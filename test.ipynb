# %%
from growwapi import GrowwAPI

# %%
# Groww API Credentials (Replace with your actual credentials)
API_AUTH_TOKEN = "eyJraWQiOiJaTUtjVXciLCJhbGciOiJFUzI1NiJ9.....PZJWS0tlqQ5NsxXOkGaIoxqX1dDYEeQ2lMgoJMB8YHkTeBIYWlZ6rhvsjRgnfQruRXcaf4Uf7TvEokkU1ly-mw"

# %%
 
# Initialize Groww API
groww = GrowwAPI(API_AUTH_TOKEN)
# Out:
# Ready to Groww!

# %%
instruments_df = groww.get_all_instruments()
# Out:
#   exchange exchange_token     trading_symbol                groww_symbol name  \
# 0      NSE          68533  360ONE26FEB1200PE  NSE-360ONE-24Feb26-1200-PE  NaN
# 1      NSE          56984  360ONE26FEB1140PE  NSE-360ONE-24Feb26-1140-PE  NaN
# 2      NSE          74919   360ONE26MAR780PE   NSE-360ONE-30Mar26-780-PE  NaN
# 3      NSE          75056  360ONE26APR1000PE  NSE-360ONE-28Apr26-1000-PE  NaN
# 4      NSE          68507   360ONE26FEB960PE   NSE-360ONE-24Feb26-960-PE  NaN
#
#   instrument_type segment series isin underlying_symbol  ... expiry_date  \
# 0              PE     FNO    NaN  NaN            360ONE  ...  2026-02-24
# 1              PE     FNO    NaN  NaN            360ONE  ...  2026-02-24
# 2              PE     FNO    NaN  NaN            360ONE  ...  2026-03-30
# 3              PE     FNO    NaN  NaN            360ONE  ...  2026-04-28
# 4              PE     FNO    NaN  NaN            360ONE  ...  2026-02-24
#
# ...

# %%
instruments_df.to_csv("instruments.csv")

# %%
quote_response = groww.get_quote(
    exchange=groww.EXCHANGE_NSE,
    segment=groww.SEGMENT_CASH,
    trading_symbol="RELIANCE"
)
# print(quote_response)
# Out:
# ---------------------------------------------------------------------------
# GrowwAPIAuthenticationException           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 quote_response = groww.get_quote(
#       2     exchange=groww.EXCHANGE_NSE,
#       3     segment=groww.SEGMENT_CASH,
#       4     trading_symbol="RELIANCE"
#       5 )
#       6 # print(quote_response)
#
# File d:\Crazy-Shit\ML_Project\StockSense-Intelligence-Platform\.venv\Lib\site-packages\growwapi\groww\client.py:400, in GrowwAPI.get_quote(self, trading_symbol, exchange, segment, timeout)
#     389 params = {
#     390     "exchange": exchange,
#     391     "segment": segment,
#     392     "trading_symbol": trading_symbol,
#     393 }
#     394 response = self._request_get(
#     395     url=url,
#     396     headers=GrowwAPI._build_headers(self.token),
#     397     params=params,
#     398     timeout=timeout,
#     399 )
# --> 400 return self._parse_response(response)
#
# ...
